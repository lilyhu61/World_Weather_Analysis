# %% [markdown]
# ## Deliverable 1: Retrieve Weather Data

# %%
# Import the dependencies.
import pandas as pd
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 617

# %%
# Import the requests library.
import requests

# Import the API key.
from config1 import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_descr = city_weather["weather"][0]["description"]
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_descr})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saint-philippe
# Processing Record 2 of Set 1 | nieuw nickerie
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | oro valley
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | dixon
# Processing Record 7 of Set 1 | kapaa
# Processing Record 8 of Set 1 | kutum
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | sept-iles
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | escanaba
# Processing Record 13 of Set 1 | mezen
# Processing Record 14 of Set 1 | solnechnyy
# Processing Record 15 of Set 1 | bredasdorp
# Processing Record 16 of Set 1 | tasiilaq
# Processing Record 17 of Set 1 | adrar
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | pangnirtung
# Processing Record 20 of Set 1 | sant julia de loria
# Processing Record 21 of Set 1 | blairmore
# Processing Record 22 of Set 1 | teahupoo
# Processing Record 23 of Set 1 | terre haute
# Processing Record 24 of Set 1 | zhanaozen
# Processing Record 25 of Set 1 | butaritari
# Processing Record 26 of Set 1 | sitka
# Processing Record 27 of Set 1 | anchorage
# Processing Record 28 of Set 1 | bezhetsk
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | zolotinka
# City not found. Skipping...
# Processing Record 31 of Set 1 | torbay
# Processing Record 32 of Set 1 | mathathane
# Processing Record 33 of Set 1 | chuy
# Processing Record 34 of Set 1 | la ronge
# Processing Record 35 of Set 1 | mineral wells
# Processing Record 36 of Set 1 | katsuura
# Processing Record 37 of Set 1 | wana
# Processing Record 38 of Set 1 | grand gaube
# Processing Record 39 of Set 1 | buala
# Processing Record 40 of Set 1 | georgetown
# Processing Record 41 of Set 1 | qui nhon
# Processing Record 42 of Set 1 | pisco
# Processing Record 43 of Set 1 | mahebourg
# Processing Record 44 of Set 1 | andenes
# Processing Record 45 of Set 1 | jiddah
# City not found. Skipping...
# Processing Record 46 of Set 1 | jiayuguan
# Processing Record 47 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 1 | zabol
# Processing Record 49 of Set 1 | ballina
# Processing Record 50 of Set 1 | maine-soroa
# Processing Record 1 of Set 2 | busselton
# Processing Record 2 of Set 2 | sao gabriel da cachoeira
# Processing Record 3 of Set 2 | pozo colorado
# Processing Record 4 of Set 2 | assiniboia
# Processing Record 5 of Set 2 | jamestown
# Processing Record 6 of Set 2 | huttwil
# Processing Record 7 of Set 2 | egvekinot
# Processing Record 8 of Set 2 | wajima
# Processing Record 9 of Set 2 | policoro
# Processing Record 10 of Set 2 | svetlyy
# Processing Record 11 of Set 2 | hami
# Processing Record 12 of Set 2 | wajid
# Processing Record 13 of Set 2 | albufeira
# Processing Record 14 of Set 2 | tutoia
# Processing Record 15 of Set 2 | savinskiy
# Processing Record 16 of Set 2 | atuona
# Processing Record 17 of Set 2 | broome
# Processing Record 18 of Set 2 | cape town
# Processing Record 19 of Set 2 | port alfred
# Processing Record 20 of Set 2 | arraial do cabo
# Processing Record 21 of Set 2 | codrington
# Processing Record 22 of Set 2 | hermanus
# Processing Record 23 of Set 2 | khatanga
# Processing Record 24 of Set 2 | thompson
# Processing Record 25 of Set 2 | klaksvik
# Processing Record 26 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 2 | nikolskoye
# Processing Record 28 of Set 2 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 29 of Set 2 | talnakh
# Processing Record 30 of Set 2 | hay river
# Processing Record 31 of Set 2 | hithadhoo
# Processing Record 32 of Set 2 | carutapera
# Processing Record 33 of Set 2 | barrow
# Processing Record 34 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 2 | hilo
# Processing Record 36 of Set 2 | avarua
# Processing Record 37 of Set 2 | the valley
# Processing Record 38 of Set 2 | kahului
# Processing Record 39 of Set 2 | san patricio
# Processing Record 40 of Set 2 | maniitsoq
# Processing Record 41 of Set 2 | zhuhai
# Processing Record 42 of Set 2 | labuan
# Processing Record 43 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 2 | east london
# Processing Record 45 of Set 2 | bluff
# Processing Record 46 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 2 | longlac
# City not found. Skipping...
# Processing Record 48 of Set 2 | longyearbyen
# Processing Record 49 of Set 2 | cherskiy
# Processing Record 50 of Set 2 | tura
# Processing Record 1 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 3 | qaanaaq
# Processing Record 3 of Set 3 | neiafu
# Processing Record 4 of Set 3 | provideniya
# Processing Record 5 of Set 3 | hamilton
# Processing Record 6 of Set 3 | buraydah
# Processing Record 7 of Set 3 | kavieng
# Processing Record 8 of Set 3 | russell
# Processing Record 9 of Set 3 | yerbogachen
# Processing Record 10 of Set 3 | oroville
# Processing Record 11 of Set 3 | puri
# Processing Record 12 of Set 3 | sao filipe
# Processing Record 13 of Set 3 | lavrentiya
# Processing Record 14 of Set 3 | mokokchung
# Processing Record 15 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 16 of Set 3 | sakakah
# Processing Record 17 of Set 3 | berezovyy
# Processing Record 18 of Set 3 | carnarvon
# Processing Record 19 of Set 3 | achisay
# City not found. Skipping...
# Processing Record 20 of Set 3 | bethel
# Processing Record 21 of Set 3 | khora
# Processing Record 22 of Set 3 | kavaratti
# Processing Record 23 of Set 3 | ruwi
# Processing Record 24 of Set 3 | boma
# Processing Record 25 of Set 3 | pringsewu
# Processing Record 26 of Set 3 | tiznit
# Processing Record 27 of Set 3 | puerto ayora
# Processing Record 28 of Set 3 | geraldton
# Processing Record 29 of Set 3 | dakar
# Processing Record 30 of Set 3 | fortuna
# Processing Record 31 of Set 3 | pontes e lacerda
# Processing Record 32 of Set 3 | ambon
# Processing Record 33 of Set 3 | hasaki
# Processing Record 34 of Set 3 | port hardy
# Processing Record 35 of Set 3 | hobart
# Processing Record 36 of Set 3 | kouango
# Processing Record 37 of Set 3 | launceston
# Processing Record 38 of Set 3 | saint-vallier
# Processing Record 39 of Set 3 | monrovia
# Processing Record 40 of Set 3 | alice springs
# Processing Record 41 of Set 3 | guerrero negro
# Processing Record 42 of Set 3 | vestmannaeyjar
# Processing Record 43 of Set 3 | rawson
# Processing Record 44 of Set 3 | ribeira grande
# Processing Record 45 of Set 3 | camacha
# Processing Record 46 of Set 3 | roald
# Processing Record 47 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 3 | nisia floresta
# Processing Record 49 of Set 3 | deputatskiy
# Processing Record 50 of Set 3 | lhokseumawe
# Processing Record 1 of Set 4 | chokurdakh
# Processing Record 2 of Set 4 | buta
# Processing Record 3 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 4 | salinopolis
# Processing Record 5 of Set 4 | santa maria
# Processing Record 6 of Set 4 | saint-pierre
# Processing Record 7 of Set 4 | college
# Processing Record 8 of Set 4 | skjervoy
# Processing Record 9 of Set 4 | prestea
# Processing Record 10 of Set 4 | bengkulu
# Processing Record 11 of Set 4 | muros
# Processing Record 12 of Set 4 | taltal
# Processing Record 13 of Set 4 | qaqortoq
# Processing Record 14 of Set 4 | bilma
# Processing Record 15 of Set 4 | mar del plata
# Processing Record 16 of Set 4 | tripoli
# Processing Record 17 of Set 4 | lompoc
# Processing Record 18 of Set 4 | patitirion
# Processing Record 19 of Set 4 | hofn
# Processing Record 20 of Set 4 | wahran
# City not found. Skipping...
# Processing Record 21 of Set 4 | kruisfontein
# Processing Record 22 of Set 4 | harer
# Processing Record 23 of Set 4 | tuktoyaktuk
# Processing Record 24 of Set 4 | cidreira
# Processing Record 25 of Set 4 | maghama
# City not found. Skipping...
# Processing Record 26 of Set 4 | ostersund
# Processing Record 27 of Set 4 | rosarito
# Processing Record 28 of Set 4 | sidi ali
# Processing Record 29 of Set 4 | karamea
# City not found. Skipping...
# Processing Record 30 of Set 4 | suifenhe
# Processing Record 31 of Set 4 | severo-kurilsk
# Processing Record 32 of Set 4 | kieta
# Processing Record 33 of Set 4 | krasnoselkup
# Processing Record 34 of Set 4 | visby
# Processing Record 35 of Set 4 | new norfolk
# Processing Record 36 of Set 4 | sabancuy
# Processing Record 37 of Set 4 | upernavik
# Processing Record 38 of Set 4 | port antonio
# Processing Record 39 of Set 4 | kaitangata
# Processing Record 40 of Set 4 | westport
# Processing Record 41 of Set 4 | peace river
# Processing Record 42 of Set 4 | dikson
# Processing Record 43 of Set 4 | namibe
# Processing Record 44 of Set 4 | ilhabela
# Processing Record 45 of Set 4 | seymchan
# Processing Record 46 of Set 4 | san juan
# Processing Record 47 of Set 4 | atambua
# Processing Record 48 of Set 4 | arlit
# Processing Record 49 of Set 4 | mount gambier
# Processing Record 50 of Set 4 | salalah
# Processing Record 1 of Set 5 | la romana
# Processing Record 2 of Set 5 | honiara
# Processing Record 3 of Set 5 | pacific grove
# Processing Record 4 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 5 | empalme
# Processing Record 6 of Set 5 | tshikapa
# Processing Record 7 of Set 5 | pemangkat
# Processing Record 8 of Set 5 | san cristobal
# Processing Record 9 of Set 5 | santa lucia
# Processing Record 10 of Set 5 | alyangula
# Processing Record 11 of Set 5 | victoria
# Processing Record 12 of Set 5 | zhigansk
# Processing Record 13 of Set 5 | chabahar
# Processing Record 14 of Set 5 | yellowknife
# Processing Record 15 of Set 5 | tiksi
# Processing Record 16 of Set 5 | castro
# Processing Record 17 of Set 5 | broken hill
# Processing Record 18 of Set 5 | vrangel
# Processing Record 19 of Set 5 | aklavik
# Processing Record 20 of Set 5 | saint-joseph
# Processing Record 21 of Set 5 | manica
# Processing Record 22 of Set 5 | ihosy
# Processing Record 23 of Set 5 | bubaque
# Processing Record 24 of Set 5 | korla
# Processing Record 25 of Set 5 | brae
# Processing Record 26 of Set 5 | tuatapere
# Processing Record 27 of Set 5 | watsa
# Processing Record 28 of Set 5 | miri
# Processing Record 29 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 5 | ahvaz
# Processing Record 31 of Set 5 | lapy
# Processing Record 32 of Set 5 | wembley
# Processing Record 33 of Set 5 | lagoa
# Processing Record 34 of Set 5 | marsh harbour
# Processing Record 35 of Set 5 | denpasar
# Processing Record 36 of Set 5 | haysyn
# Processing Record 37 of Set 5 | kogon
# Processing Record 38 of Set 5 | billings
# Processing Record 39 of Set 5 | saskylakh
# Processing Record 40 of Set 5 | oum hadjer
# Processing Record 41 of Set 5 | assen
# Processing Record 42 of Set 5 | pangai
# Processing Record 43 of Set 5 | tessalit
# Processing Record 44 of Set 5 | bethanien
# Processing Record 45 of Set 5 | cheuskiny
# City not found. Skipping...
# Processing Record 46 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 47 of Set 5 | sumbe
# Processing Record 48 of Set 5 | rio gallegos
# Processing Record 49 of Set 5 | elat
# Processing Record 50 of Set 5 | yumen
# Processing Record 1 of Set 6 | freeport
# Processing Record 2 of Set 6 | oranjemund
# Processing Record 3 of Set 6 | kalpi
# Processing Record 4 of Set 6 | jian
# Processing Record 5 of Set 6 | laguna
# Processing Record 6 of Set 6 | faanui
# Processing Record 7 of Set 6 | kisangani
# Processing Record 8 of Set 6 | gwadar
# Processing Record 9 of Set 6 | revelstoke
# Processing Record 10 of Set 6 | steamboat springs
# Processing Record 11 of Set 6 | kropotkin
# Processing Record 12 of Set 6 | solec kujawski
# Processing Record 13 of Set 6 | solovetskiy
# City not found. Skipping...
# Processing Record 14 of Set 6 | pevek
# Processing Record 15 of Set 6 | alihe
# Processing Record 16 of Set 6 | bambous virieux
# Processing Record 17 of Set 6 | dawei
# Processing Record 18 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 6 | nanortalik
# Processing Record 20 of Set 6 | norman wells
# Processing Record 21 of Set 6 | cardenas
# Processing Record 22 of Set 6 | edgewater
# Processing Record 23 of Set 6 | loreto
# Processing Record 24 of Set 6 | dharchula
# Processing Record 25 of Set 6 | saldanha
# Processing Record 26 of Set 6 | bako
# Processing Record 27 of Set 6 | inhambane
# Processing Record 28 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 29 of Set 6 | sechura
# Processing Record 30 of Set 6 | varberg
# Processing Record 31 of Set 6 | leningradskiy
# Processing Record 32 of Set 6 | kholtoson
# Processing Record 33 of Set 6 | saint george
# Processing Record 34 of Set 6 | ahipara
# Processing Record 35 of Set 6 | mahdasht
# Processing Record 36 of Set 6 | copiapo
# Processing Record 37 of Set 6 | przeworsk
# Processing Record 38 of Set 6 | vila franca do campo
# Processing Record 39 of Set 6 | chapais
# Processing Record 40 of Set 6 | paamiut
# Processing Record 41 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 6 | thinadhoo
# Processing Record 43 of Set 6 | airai
# Processing Record 44 of Set 6 | nuuk
# Processing Record 45 of Set 6 | saint-francois
# Processing Record 46 of Set 6 | tecoanapa
# Processing Record 47 of Set 6 | cabo san lucas
# Processing Record 48 of Set 6 | koungou
# Processing Record 49 of Set 6 | nelipyno
# Processing Record 50 of Set 6 | shahrud
# Processing Record 1 of Set 7 | amapa
# Processing Record 2 of Set 7 | verkhoyansk
# Processing Record 3 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 7 | victor harbor
# Processing Record 5 of Set 7 | crotone
# Processing Record 6 of Set 7 | alofi
# Processing Record 7 of Set 7 | esperance
# Processing Record 8 of Set 7 | los llanos de aridane
# Processing Record 9 of Set 7 | nara
# Processing Record 10 of Set 7 | ilo
# Processing Record 11 of Set 7 | mangan
# Processing Record 12 of Set 7 | mehamn
# Processing Record 13 of Set 7 | tsiroanomandidy
# Processing Record 14 of Set 7 | krasnyy yar
# Processing Record 15 of Set 7 | goderich
# Processing Record 16 of Set 7 | daru
# Processing Record 17 of Set 7 | arkhangelsk
# Processing Record 18 of Set 7 | antofagasta
# Processing Record 19 of Set 7 | terrace
# Processing Record 20 of Set 7 | nome
# Processing Record 21 of Set 7 | puerto rico
# Processing Record 22 of Set 7 | baykit
# Processing Record 23 of Set 7 | dingle
# Processing Record 24 of Set 7 | mende
# Processing Record 25 of Set 7 | hammerfest
# Processing Record 26 of Set 7 | haines junction
# Processing Record 27 of Set 7 | koslan
# Processing Record 28 of Set 7 | nosy varika
# Processing Record 29 of Set 7 | murgab
# Processing Record 30 of Set 7 | naze
# Processing Record 31 of Set 7 | ulladulla
# Processing Record 32 of Set 7 | weligama
# Processing Record 33 of Set 7 | dhidhdhoo
# Processing Record 34 of Set 7 | san quintin
# Processing Record 35 of Set 7 | katobu
# Processing Record 36 of Set 7 | great yarmouth
# Processing Record 37 of Set 7 | selvazzano dentro
# Processing Record 38 of Set 7 | clyde river
# Processing Record 39 of Set 7 | tupelo
# Processing Record 40 of Set 7 | ikirun
# Processing Record 41 of Set 7 | bellary
# Processing Record 42 of Set 7 | saint-augustin
# Processing Record 43 of Set 7 | te anau
# Processing Record 44 of Set 7 | kuching
# Processing Record 45 of Set 7 | moville
# Processing Record 46 of Set 7 | ostrovnoy
# Processing Record 47 of Set 7 | kaa-khem
# Processing Record 48 of Set 7 | zverinogolovskoye
# Processing Record 49 of Set 7 | riberalta
# Processing Record 50 of Set 7 | pitimbu
# Processing Record 1 of Set 8 | amboasary
# Processing Record 2 of Set 8 | port lincoln
# Processing Record 3 of Set 8 | kuala terengganu
# Processing Record 4 of Set 8 | rajgarh
# Processing Record 5 of Set 8 | hilliard
# Processing Record 6 of Set 8 | ilulissat
# Processing Record 7 of Set 8 | samfya
# Processing Record 8 of Set 8 | vage
# Processing Record 9 of Set 8 | ancud
# Processing Record 10 of Set 8 | comodoro rivadavia
# Processing Record 11 of Set 8 | sukhobuzimskoye
# Processing Record 12 of Set 8 | port shepstone
# Processing Record 13 of Set 8 | brunico
# Processing Record 14 of Set 8 | port elizabeth
# Processing Record 15 of Set 8 | galiwinku
# City not found. Skipping...
# Processing Record 16 of Set 8 | bayan
# Processing Record 17 of Set 8 | moa
# Processing Record 18 of Set 8 | lewiston
# Processing Record 19 of Set 8 | svetlogorsk
# Processing Record 20 of Set 8 | tagusao
# Processing Record 21 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 8 | kodiak
# Processing Record 23 of Set 8 | ayacucho
# Processing Record 24 of Set 8 | aginskoye
# Processing Record 25 of Set 8 | magadan
# Processing Record 26 of Set 8 | ruidoso
# Processing Record 27 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 28 of Set 8 | manjakandriana
# Processing Record 29 of Set 8 | pingzhuang
# Processing Record 30 of Set 8 | gat
# Processing Record 31 of Set 8 | mehran
# Processing Record 32 of Set 8 | calvinia
# Processing Record 33 of Set 8 | cubuk
# Processing Record 34 of Set 8 | tautira
# Processing Record 35 of Set 8 | rancho palos verdes
# Processing Record 36 of Set 8 | ilesha
# Processing Record 37 of Set 8 | portland
# Processing Record 38 of Set 8 | tiarei
# Processing Record 39 of Set 8 | togur
# Processing Record 40 of Set 8 | kampot
# Processing Record 41 of Set 8 | gao
# Processing Record 42 of Set 8 | kingaroy
# Processing Record 43 of Set 8 | visnes
# Processing Record 44 of Set 8 | bereda
# Processing Record 45 of Set 8 | faya
# Processing Record 46 of Set 8 | lodja
# Processing Record 47 of Set 8 | sankt veit
# Processing Record 48 of Set 8 | qena
# Processing Record 49 of Set 8 | tomohon
# Processing Record 50 of Set 8 | vao
# Processing Record 1 of Set 9 | crab hill
# City not found. Skipping...
# Processing Record 2 of Set 9 | bagotville
# Processing Record 3 of Set 9 | karasburg
# Processing Record 4 of Set 9 | shimoda
# Processing Record 5 of Set 9 | djenne
# Processing Record 6 of Set 9 | boa vista
# Processing Record 7 of Set 9 | beya
# Processing Record 8 of Set 9 | fairmont
# Processing Record 9 of Set 9 | praia
# Processing Record 10 of Set 9 | loviisa
# Processing Record 11 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 12 of Set 9 | yaizu
# Processing Record 13 of Set 9 | belaya gora
# Processing Record 14 of Set 9 | capannori
# Processing Record 15 of Set 9 | azimur
# City not found. Skipping...
# Processing Record 16 of Set 9 | lebu
# Processing Record 17 of Set 9 | udachnyy
# Processing Record 18 of Set 9 | samarai
# Processing Record 19 of Set 9 | praia da vitoria
# Processing Record 20 of Set 9 | haverfordwest
# Processing Record 21 of Set 9 | viedma
# Processing Record 22 of Set 9 | monte alegre
# Processing Record 23 of Set 9 | bueno brandao
# Processing Record 24 of Set 9 | port-gentil
# Processing Record 25 of Set 9 | kjopsvik
# Processing Record 26 of Set 9 | kitob
# Processing Record 27 of Set 9 | eureka
# Processing Record 28 of Set 9 | hambantota
# Processing Record 29 of Set 9 | galgani
# City not found. Skipping...
# Processing Record 30 of Set 9 | terra santa
# Processing Record 31 of Set 9 | beyneu
# Processing Record 32 of Set 9 | walvis bay
# Processing Record 33 of Set 9 | nichinan
# Processing Record 34 of Set 9 | larsnes
# Processing Record 35 of Set 9 | krasnomayskiy
# Processing Record 36 of Set 9 | moctezuma
# Processing Record 37 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 9 | sataua
# City not found. Skipping...
# Processing Record 39 of Set 9 | marystown
# Processing Record 40 of Set 9 | dromolaxia
# Processing Record 41 of Set 9 | nacozari
# Processing Record 42 of Set 9 | emerald
# Processing Record 43 of Set 9 | palmas
# Processing Record 44 of Set 9 | meliki
# Processing Record 45 of Set 9 | road town
# Processing Record 46 of Set 9 | bontang
# Processing Record 47 of Set 9 | ormond beach
# Processing Record 48 of Set 9 | vila velha
# Processing Record 49 of Set 9 | pochutla
# Processing Record 50 of Set 9 | bulgan
# Processing Record 1 of Set 10 | tilichiki
# Processing Record 2 of Set 10 | price
# Processing Record 3 of Set 10 | sorland
# Processing Record 4 of Set 10 | campo maior
# Processing Record 5 of Set 10 | agirish
# Processing Record 6 of Set 10 | kwekwe
# Processing Record 7 of Set 10 | sur
# Processing Record 8 of Set 10 | maniwaki
# Processing Record 9 of Set 10 | karratha
# Processing Record 10 of Set 10 | matagami
# Processing Record 11 of Set 10 | raga
# Processing Record 12 of Set 10 | kuruman
# Processing Record 13 of Set 10 | gizo
# Processing Record 14 of Set 10 | saleilua
# City not found. Skipping...
# Processing Record 15 of Set 10 | cumra
# Processing Record 16 of Set 10 | labuhan
# Processing Record 17 of Set 10 | praya
# Processing Record 18 of Set 10 | nagapattinam
# Processing Record 19 of Set 10 | hargeysa
# Processing Record 20 of Set 10 | bathsheba
# Processing Record 21 of Set 10 | limoux
# Processing Record 22 of Set 10 | saint anthony
# Processing Record 23 of Set 10 | yagodnoye
# Processing Record 24 of Set 10 | bardiyah
# Processing Record 25 of Set 10 | the pas
# Processing Record 26 of Set 10 | agnibilekrou
# Processing Record 27 of Set 10 | tongchuan
# Processing Record 28 of Set 10 | luang prabang
# Processing Record 29 of Set 10 | zhezkazgan
# Processing Record 30 of Set 10 | limbang
# Processing Record 31 of Set 10 | colombo
# Processing Record 32 of Set 10 | korop
# Processing Record 33 of Set 10 | kaseda
# Processing Record 34 of Set 10 | san pedro
# Processing Record 35 of Set 10 | fukue
# Processing Record 36 of Set 10 | houma
# Processing Record 37 of Set 10 | humaita
# Processing Record 38 of Set 10 | bonavista
# Processing Record 39 of Set 10 | santa cruz
# Processing Record 40 of Set 10 | cap malheureux
# Processing Record 41 of Set 10 | borlange
# City not found. Skipping...
# Processing Record 42 of Set 10 | isla mujeres
# Processing Record 43 of Set 10 | richards bay
# Processing Record 44 of Set 10 | kalawit
# Processing Record 45 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 46 of Set 10 | port blair
# Processing Record 47 of Set 10 | solsvik
# City not found. Skipping...
# Processing Record 48 of Set 10 | san antonio
# Processing Record 49 of Set 10 | awbari
# Processing Record 50 of Set 10 | sobolevo
# Processing Record 1 of Set 11 | okhotsk
# Processing Record 2 of Set 11 | cabedelo
# Processing Record 3 of Set 11 | hamina
# Processing Record 4 of Set 11 | huarmey
# Processing Record 5 of Set 11 | ramshir
# Processing Record 6 of Set 11 | kidal
# Processing Record 7 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 11 | ust-omchug
# Processing Record 9 of Set 11 | chenghai
# Processing Record 10 of Set 11 | toamasina
# Processing Record 11 of Set 11 | olinda
# Processing Record 12 of Set 11 | xining
# Processing Record 13 of Set 11 | yiannitsa
# City not found. Skipping...
# Processing Record 14 of Set 11 | san luis
# Processing Record 15 of Set 11 | tynda
# Processing Record 16 of Set 11 | zachary
# Processing Record 17 of Set 11 | riyadh
# Processing Record 18 of Set 11 | padang
# Processing Record 19 of Set 11 | coihaique
# Processing Record 20 of Set 11 | araouane
# Processing Record 21 of Set 11 | nicosia
# Processing Record 22 of Set 11 | west bridgeford
# City not found. Skipping...
# Processing Record 23 of Set 11 | moron
# Processing Record 24 of Set 11 | bonfim
# Processing Record 25 of Set 11 | nuevo progreso
# Processing Record 26 of Set 11 | hovd
# Processing Record 27 of Set 11 | srednekolymsk
# Processing Record 28 of Set 11 | banmo
# City not found. Skipping...
# Processing Record 29 of Set 11 | alta floresta
# Processing Record 30 of Set 11 | requena
# Processing Record 31 of Set 11 | auki
# Processing Record 32 of Set 11 | eyrarbakki
# Processing Record 33 of Set 11 | jinchang
# Processing Record 34 of Set 11 | paucartambo
# City not found. Skipping...
# Processing Record 35 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 36 of Set 11 | romny
# Processing Record 37 of Set 11 | obihiro
# Processing Record 38 of Set 11 | salyan
# Processing Record 39 of Set 11 | vredendal
# Processing Record 40 of Set 11 | padilla
# Processing Record 41 of Set 11 | jaisalmer
# Processing Record 42 of Set 11 | fez
# Processing Record 43 of Set 11 | nanpiao
# Processing Record 44 of Set 11 | anyksciai
# Processing Record 45 of Set 11 | tual
# Processing Record 46 of Set 11 | campos belos
# Processing Record 47 of Set 11 | mme
# City not found. Skipping...
# Processing Record 48 of Set 11 | nicoya
# Processing Record 49 of Set 11 | pontianak
# Processing Record 50 of Set 11 | rudnogorsk
# Processing Record 1 of Set 12 | puerto varas
# Processing Record 2 of Set 12 | ailigandi
# Processing Record 3 of Set 12 | gorontalo
# Processing Record 4 of Set 12 | pavlodar
# Processing Record 5 of Set 12 | ejura
# Processing Record 6 of Set 12 | den helder
# Processing Record 7 of Set 12 | metro
# Processing Record 8 of Set 12 | beringovskiy
# Processing Record 9 of Set 12 | seto
# Processing Record 10 of Set 12 | madarounfa
# Processing Record 11 of Set 12 | isla vista
# Processing Record 12 of Set 12 | mazara del vallo
# Processing Record 13 of Set 12 | mozarlandia
# Processing Record 14 of Set 12 | fremont
# Processing Record 15 of Set 12 | dibulla
# Processing Record 16 of Set 12 | clovis
# Processing Record 17 of Set 12 | alekseyevsk
# Processing Record 18 of Set 12 | kindu
# Processing Record 19 of Set 12 | la primavera
# Processing Record 20 of Set 12 | hualmay
# Processing Record 21 of Set 12 | koygorodok
# Processing Record 22 of Set 12 | kastamonu
# Processing Record 23 of Set 12 | kirakira
# Processing Record 24 of Set 12 | ust-nera
# Processing Record 25 of Set 12 | miraflores
# Processing Record 26 of Set 12 | traverse city
# Processing Record 27 of Set 12 | lensk
# Processing Record 28 of Set 12 | okato
# Processing Record 29 of Set 12 | itoman
# Processing Record 30 of Set 12 | qibili
# City not found. Skipping...
# Processing Record 31 of Set 12 | myitkyina
# Processing Record 32 of Set 12 | flinders
# Processing Record 33 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 34 of Set 12 | la quinta
# Processing Record 35 of Set 12 | talcahuano
# Processing Record 36 of Set 12 | port macquarie
# Processing Record 37 of Set 12 | meulaboh
# Processing Record 38 of Set 12 | yulara
# Processing Record 39 of Set 12 | grindavik
# Processing Record 40 of Set 12 | shache
# Processing Record 41 of Set 12 | general roca
# Processing Record 42 of Set 12 | roma
# Processing Record 43 of Set 12 | naumburg
# Processing Record 44 of Set 12 | anloga
# Processing Record 45 of Set 12 | klin
# Processing Record 46 of Set 12 | orbetello
# Processing Record 47 of Set 12 | morondava
# Processing Record 48 of Set 12 | arman
# Processing Record 49 of Set 12 | filadelfia
# Processing Record 50 of Set 12 | sola
# Processing Record 1 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 2 of Set 13 | marakkanam
# Processing Record 3 of Set 13 | kermen
# Processing Record 4 of Set 13 | kabinda
# Processing Record 5 of Set 13 | abu samrah
# Processing Record 6 of Set 13 | sorong
# Processing Record 7 of Set 13 | paveh
# Processing Record 8 of Set 13 | karakendzha
# City not found. Skipping...
# Processing Record 9 of Set 13 | saraland
# Processing Record 10 of Set 13 | mananjary
# Processing Record 11 of Set 13 | liwale
# Processing Record 12 of Set 13 | dauphin
# Processing Record 13 of Set 13 | lata
# Processing Record 14 of Set 13 | igrim
# Processing Record 15 of Set 13 | verkhnyaya inta
# Processing Record 16 of Set 13 | sabya
# Processing Record 17 of Set 13 | venado
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Saint-Philippe -21.3585   55.7679     80.15        81         100
# 1  Nieuw Nickerie   5.9500  -56.9833     79.56        83          87
# 2         Ushuaia -54.8000  -68.3000     65.86        48          20
# 3      Oro Valley  32.3909 -110.9665     67.41        17           0
# 4           Vaini -21.2000 -175.2000     75.36        94         100
#
#    Wind Speed Country Current Description
# 0       14.74      RE     overcast clouds
# 1       10.65      SR     overcast clouds
# 2       13.80      AR          few clouds
# 3        1.99      US           clear sky
# 4       10.36      TO          light rain

# %%
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Saint-Philippe      RE -21.3585   55.7679     80.15        81         100
# 1  Nieuw Nickerie      SR   5.9500  -56.9833     79.56        83          87
# 2         Ushuaia      AR -54.8000  -68.3000     65.86        48          20
# 3      Oro Valley      US  32.3909 -110.9665     67.41        17           0
# 4           Vaini      TO -21.2000 -175.2000     75.36        94         100
# 5           Dixon      US  38.4455 -121.8233     67.06        59           0
# 6           Kapaa      US  22.0752 -159.3190     75.52        77          75
# 7           Kutum      SD  14.2000   24.6667     56.07        18          61
# 8         Mataura      NZ -46.1927  168.8643     47.48        74           5
# 9       Sept-Iles      CA  50.2001  -66.3821      6.06        59          40
#
#    Wind Speed Current Description
# 0       14.74     overcast clouds
# 1       10.65     overcast clouds
# 2       13.80          few clouds
# 3        1.99           clear sky
# 4       10.36          light rain
# 5        5.75           clear sky
# 6        1.99       broken clouds
# 7       12.37       broken clouds
# 8        1.28           clear sky
# 9        7.00    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
